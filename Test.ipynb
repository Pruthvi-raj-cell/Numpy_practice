# %%
import numpy as np

# %%
np.random.seed(42)
student_ids = np.arange(1 , 201)
attendance = np.clip(np.random.normal(85 , 10 , 200) , 50 , 100).round(1)
study_hours = np.clip(np.random.normal(4,2,200) , 0 , 10).round(1)
assignments_completed = np.random.randint(0 ,11 ,200)
noise = np.random.normal(0 , 8 , 200)

marks = np.clip(
    40 + attendance * 0.3 + study_hours * 4 + assignments_completed*1.5 +noise , 0 , 100
).round(1)

# %%
marks.max()
# Out:
# np.float64(100.0)

# %%
marks.min(
)
# Out:
# np.float64(57.7)

# %%
np.median(marks)
# Out:
# np.float64(92.05)

# %%
marks.mean()
# Out:
# np.float64(88.6515)

# %%
marks.var(
)
# Out:
# np.float64(108.90439775)

# %%
marks.std()
# Out:
# np.float64(10.43572698713415)

# %%
student_ids[marks > 90]
# Out:
# array([  1,   3,   4,   7,   8,   9,  10,  11,  12,  14,  16,  17,  21,
#         25,  30,  32,  33,  35,  36,  40,  42,  43,  44,  49,  52,  53,
#         54,  56,  57,  62,  67,  69,  71,  72,  73,  77,  83,  84,  85,
#         86,  87,  88,  89,  91,  92,  93,  94,  95,  97,  99, 103, 104,
#        105, 106, 107, 109, 112, 114, 115, 116, 119, 120, 121, 122, 124,
#        127, 128, 129, 135, 138, 139, 142, 149, 151, 152, 155, 156, 158,
#        159, 162, 163, 164, 165, 167, 168, 170, 172, 173, 175, 177, 178,
#        179, 181, 186, 187, 188, 189, 190, 192, 194, 195, 196, 198, 199,
#        200])

# %%
student_ids[(marks > 80) & (attendance > 90)]
# Out:
# array([  3,   4,   7,   8,  10,  21,  32,  35,  41,  48,  54,  56,  68,
#         72,  74,  76,  83,  87,  90,  92, 107, 114, 119, 120, 121, 123,
#        136, 139, 142, 149, 160, 162, 163, 165, 167, 168, 176, 178, 180,
#        181, 186, 192])
