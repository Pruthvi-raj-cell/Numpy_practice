# %%
import numpy as np

# %%
name = "pruthvi"
name
# Out:
# 'pruthvi'

# %%
arr = np.array([3,8,3,5,3,7])
arr
# Out:
# array([3, 8, 3, 5, 3, 7])

# %%
# numpy arr are like arr in java only one data type are allowed in the arr

# %%
name = np.array([34,"raj" , 3])
name
# now here all the values in the arr are string therefore the access is faster
# Out:
# array(['34', 'raj', '3'], dtype='<U21')

# %%
name[2]
# Out:
# np.str_('3')

# %%
name1 = [3,3,32,245]
name1[2]
# Out:
# 32

# %%
# see the diff in the ms to return the index
